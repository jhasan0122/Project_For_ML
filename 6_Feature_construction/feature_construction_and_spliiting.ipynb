# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score

# %%
df = pd.read_csv('train.csv')[['Age','Pclass','SibSp','Parch','Survived']]
df
# Out:
#       Age  Pclass  SibSp  Parch  Survived
# 0    22.0       3      1      0         0
# 1    38.0       1      1      0         1
# 2    26.0       3      0      0         1
# 3    35.0       1      1      0         1
# 4    35.0       3      0      0         0
# ..    ...     ...    ...    ...       ...
# 886  27.0       2      0      0         0
# 887  19.0       1      0      0         1
# 888   NaN       3      1      2         0
# 889  26.0       1      0      0         1
# 890  32.0       3      0      0         0
#
# [891 rows x 5 columns]

# %%
df.dropna(inplace=True)

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X
# Out:
#       Age  Pclass  SibSp  Parch
# 0    22.0       3      1      0
# 1    38.0       1      1      0
# 2    26.0       3      0      0
# 3    35.0       1      1      0
# 4    35.0       3      0      0
# ..    ...     ...    ...    ...
# 885  39.0       3      0      5
# 886  27.0       2      0      0
# 887  19.0       1      0      0
# 889  26.0       1      0      0
# 890  32.0       3      0      0
#
# [714 rows x 4 columns]

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 885    0
# 886    0
# 887    1
# 889    1
# 890    0
# Name: Survived, Length: 714, dtype: int64

# %%
np.mean(cross_val_score(LogisticRegression(),X,y,scoring='accuracy',cv=10))
# Out:
# 0.6921165884194054

# %% [markdown]
# # Applying Feature Construction

# %%
df['Family_size'] = df['SibSp'] + df['Parch'] + 1
df
# Out:
#       Age  Pclass  SibSp  Parch  Survived  Family_size
# 0    22.0       3      1      0         0            2
# 1    38.0       1      1      0         1            2
# 2    26.0       3      0      0         1            1
# 3    35.0       1      1      0         1            2
# 4    35.0       3      0      0         0            1
# ..    ...     ...    ...    ...       ...          ...
# 885  39.0       3      0      5         0            6
# 886  27.0       2      0      0         0            1
# 887  19.0       1      0      0         1            1
# 889  26.0       1      0      0         1            1
# 890  32.0       3      0      0         0            1
#
# [714 rows x 6 columns]

# %%
def fam(size):
    if size == 1:
        return 0
    elif size <= 4:
        return 1
    else:
        return 2

# %%
df['Family_type'] = df['Family_size'].apply(fam)
df
# Out:
#       Age  Pclass  SibSp  Parch  Survived  Family_size  Family_type
# 0    22.0       3      1      0         0            2            1
# 1    38.0       1      1      0         1            2            1
# 2    26.0       3      0      0         1            1            0
# 3    35.0       1      1      0         1            2            1
# 4    35.0       3      0      0         0            1            0
# ..    ...     ...    ...    ...       ...          ...          ...
# 885  39.0       3      0      5         0            6            2
# 886  27.0       2      0      0         0            1            0
# 887  19.0       1      0      0         1            1            0
# 889  26.0       1      0      0         1            1            0
# 890  32.0       3      0      0         0            1            0
#
# [714 rows x 7 columns]

# %%
df.drop(columns=['SibSp','Parch','Family_size'],inplace=True)

# %%
df
# Out:
#       Age  Pclass  Survived  Family_type
# 0    22.0       3         0            1
# 1    38.0       1         1            1
# 2    26.0       3         1            0
# 3    35.0       1         1            1
# 4    35.0       3         0            0
# ..    ...     ...       ...          ...
# 885  39.0       3         0            2
# 886  27.0       2         0            0
# 887  19.0       1         1            0
# 889  26.0       1         1            0
# 890  32.0       3         0            0
#
# [714 rows x 4 columns]

# %%
X = df[['Age','Pclass','Family_type']]
y = df[['Survived']]

# %%
X
# Out:
#       Age  Pclass  Family_type
# 0    22.0       3            1
# 1    38.0       1            1
# 2    26.0       3            0
# 3    35.0       1            1
# 4    35.0       3            0
# ..    ...     ...          ...
# 885  39.0       3            2
# 886  27.0       2            0
# 887  19.0       1            0
# 889  26.0       1            0
# 890  32.0       3            0
#
# [714 rows x 3 columns]

# %%
y
# Out:
#      Survived
# 0           0
# 1           1
# 2           1
# 3           1
# 4           0
# ..        ...
# 885         0
# 886         0
# 887         1
# 889         1
# 890         0
#
# [714 rows x 1 columns]

# %%
np.mean(cross_val_score(LogisticRegression(), X, y, scoring='accuracy', cv=10))
# Out:
# C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %% [markdown]
# # Features splitting

# %%
df = pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Title'] = df['Name'].str.split(', ',expand=True)[1].str.split('. ',expand=True)[0]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# th            1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: count, dtype: int64

# %%
df['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Don', 'Rev', 'Dr', 'Mme', 'Ms',
#        'Major', 'Lady', 'Sir', 'Mlle', 'Col', 'Capt', 'th', 'Jonkheer'],
#       dtype=object)

# %%
df['Is_married'] = 0
df['Is_married'].iloc[df['Title'] == 'Mrs'] = 1
df
# Out:
# C:\Users\HP TECHNOLOGY\AppData\Local\Temp\ipykernel_7460\1620606144.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Is_married'].iloc[df['Title'] == 'Mrs'] = 1
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# ...
