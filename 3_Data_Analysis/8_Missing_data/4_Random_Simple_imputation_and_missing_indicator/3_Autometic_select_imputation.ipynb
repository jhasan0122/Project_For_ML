# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split, GridSearchCV

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv('train.csv')
df.drop(columns=['PassengerId','Name','Ticket','Cabin'],inplace=True)
df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df.isnull().mean() *100
# Out:
# Survived     0.000000
# Pclass       0.000000
# Sex          0.000000
# Age         19.865320
# SibSp        0.000000
# Parch        0.000000
# Fare         0.000000
# Embarked     0.224467
# dtype: float64

# %%
X = df.drop(columns=['Survived'])
y = df['Survived']

# %%
X_train, X_test , y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 30        1    male  40.0      0      0   27.7208        C
# 10        3  female   4.0      1      1   16.7000        S
# 873       3    male  47.0      0      0    9.0000        S
# 182       3    male   9.0      4      2   31.3875        S
# 876       3    male  20.0      0      0    9.8458        S
# ..      ...     ...   ...    ...    ...       ...      ...
# 534       3  female  30.0      0      0    8.6625        S
# 584       3    male   NaN      0      0    8.7125        C
# 493       1    male  71.0      0      0   49.5042        C
# 527       1    male   NaN      0      0  221.7792        S
# 168       1    male   NaN      0      0   25.9250        S
#
# [712 rows x 7 columns]

# %%
X_train.isnull().mean()
# Out:
# Pclass      0.000000
# Sex         0.000000
# Age         0.207865
# SibSp       0.000000
# Parch       0.000000
# Fare        0.000000
# Embarked    0.002809
# dtype: float64

# %% [markdown]
# # Imputer + Scaling

# %%
numerical_features = ['Age','Fare']
numerical_transformer = Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='mean')),
        ('scaler',StandardScaler())
    ]
)


categorical_features = ['Sex','Embarked']
categorical_transformer = Pipeline(
    steps=[
        ('imputer',SimpleImputer(strategy='most_frequent')),
        ('ohe',OneHotEncoder(handle_unknown='ignore'))
    ]
)

# %% [markdown]
# # Using Transformer

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('num',numerical_transformer,numerical_features),
        ('cat',categorical_transformer,categorical_features)
    ],remainder='passthrough'
)

# %% [markdown]
# # Logistic regression

# %%
clf = Pipeline(
    steps=[
        ('preprocessor',preprocessor),
        ('classifier',LogisticRegression())
    ]
)

# %% [markdown]
# # Diagram Draw

# %%
from sklearn import set_config

set_config(display='diagram')
clf
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    StandardScaler())]),
#                                                   ['Age', 'Fare']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('ohe',
#                                                                    OneHotEncoder(handle_unknown='ignore'))]),
#                                                   ['Sex', 'Embarked'])])),
#                 ('classifier', LogisticRegression())])

# %%
from sklearn.preprocessing import MinMaxScaler
param_grid = {
    'preprocessor__num__imputer__strategy' : ['mean','meadian'],
    'preprocessor__num__scaler' : [StandardScaler(),MinMaxScaler()],
    'preprocessor__cat__imputer__strategy' : ['most_frequent','constant'],
    'classifier__C': [0.1, 1.0, 10, 100]
}

grid_search = GridSearchCV(clf,param_grid,cv=10)

# %%
grid_search.fit(X_train, y_train)

print(f"Best params: {grid_search.best_params_}")
# Out:
# Best params: {'classifier__C': 0.1, 'preprocessor__cat__imputer__strategy': 'most_frequent', 'preprocessor__num__imputer__strategy': 'mean', 'preprocessor__num__scaler': StandardScaler()}
# C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py:378: FitFailedWarning:
# 160 fits failed out of a total of 320.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 160 fits failed with the following error:
# Traceback (most recent call last):
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\model_selection\_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 401, in fit
#     Xt = self._fit(X, y, **fit_params_steps)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 359, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py", line 727, in fit_transform
#     result = self._fit_transform(X, y, _fit_transform_one)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\compose\_column_transformer.py", line 658, in _fit_transform
#     return Parallel(n_jobs=self.n_jobs)(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\utils\parallel.py", line 63, in __call__
#     return super().__call__(iterable_with_config)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\joblib\parallel.py", line 1048, in __call__
#     if self.dispatch_one_batch(iterator):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\joblib\parallel.py", line 864, in dispatch_one_batch
#     self._dispatch(tasks)
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\joblib\parallel.py", line 782, in _dispatch
#     job = self._backend.apply_async(batch, callback=cb)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\joblib\_parallel_backends.py", line 208, in apply_async
#     result = ImmediateResult(func)
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\joblib\_parallel_backends.py", line 572, in __init__
#     self.results = batch()
#                    ^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\joblib\parallel.py", line 263, in __call__
#     return [func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\joblib\parallel.py", line 263, in <listcomp>
#     return [func(*args, **kwargs)
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\utils\parallel.py", line 123, in __call__
#     return self.function(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 437, in fit_transform
#     Xt = self._fit(X, y, **fit_params_steps)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 359, in _fit
#     X, fitted_transformer = fit_transform_one_cached(
#                             ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\joblib\memory.py", line 349, in __call__
#     return self.func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\pipeline.py", line 893, in _fit_transform_one
#     res = transformer.fit_transform(X, y, **fit_params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\utils\_set_output.py", line 140, in wrapped
#     data_to_wrap = f(self, X, *args, **kwargs)
#                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\base.py", line 881, in fit_transform
#     return self.fit(X, y, **fit_params).transform(X)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\impute\_base.py", line 380, in fit
#     self._validate_params()
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\utils\_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'strategy' parameter of SimpleImputer must be a str among {'mean', 'median', 'most_frequent', 'constant'}. Got 'meadian' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# C:\Users\HP TECHNOLOGY\anaconda3\Lib\site-packages\sklearn\model_selection\_search.py:952: UserWarning: One or more of the test scores are non-finite: [0.81171753 0.79908059        nan        nan 0.81030908 0.79908059
#         nan        nan 0.80608372 0.80465571        nan        nan
#  0.80608372 0.80324726        nan        nan 0.80467527 0.80608372
#         nan        nan 0.80328638 0.80469484        nan        nan
#  0.80328638 0.80328638        nan        nan 0.80328638 0.80328638
#         nan        nan]
#   warnings.warn(

# %%
print(f"Internal CV score {grid_search.best_score_}")
# Out:
# Internal CV score 0.8117175273865416

# %%
cv_results = pd.DataFrame(grid_search.cv_results_)
cv_results = cv_results.sort_values("mean_test_score",ascending=False)
cv_results
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.009013  6.445429e-04         0.003423        0.000501
# 4        0.007802  4.000664e-04         0.002701        0.000459
# 8        0.008409  6.699075e-04         0.002703        0.000460
# 12       0.009034  5.875694e-04         0.002801        0.000400
# 17       0.009702  6.403517e-04         0.002801        0.000400
# 21       0.011703  9.001970e-04         0.002901        0.000539
# 16       0.008502  5.001784e-04         0.002601        0.000490
# 9        0.008807  4.030255e-04         0.002702        0.000459
# 20       0.009908  5.301616e-04         0.002901        0.000539
# 24       0.009701  4.580485e-04         0.003201        0.000400
# 25       0.010703  4.584690e-04         0.002900        0.000300
# 28       0.011069  6.632459e-04         0.003021        0.000635
# 29       0.013403  1.200457e-03         0.003101        0.000300
# 13       0.009402  4.900085e-04         0.002601        0.000490
# 1        0.008828  8.704138e-04         0.003307        0.000454
# 5        0.008702  2.238918e-03         0.003901        0.000943
# 2        0.001101  3.010910e-04         0.000000        0.000000
# 3        0.001000  2.622604e-07         0.000000        0.000000
# 6        0.001200  3.998757e-04         0.000000        0.000000
# 7        0.001407  4.865455e-04         0.000000        0.000000
# 10       0.001000  1.599360e-07         0.000000        0.000000
# 11       0.001100  2.999783e-04         0.000000        0.000000
# 14       0.001200  4.001380e-04         0.000000        0.000000
# 15       0.001100  2.999862e-04         0.000000        0.000000
# 18       0.001100  3.000340e-04         0.000000        0.000000
# 19       0.001000  7.152557e-08         0.000000        0.000000
# 22       0.001400  4.901740e-04         0.000000        0.000000
# 23       0.001500  5.001546e-04         0.000000        0.000000
# 26       0.001000  1.980453e-07         0.000000        0.000000
# 27       0.001000  1.211955e-06         0.000000        0.000000
# 30       0.001203  4.049704e-04         0.000000        0.000000
# 31       0.001100  3.000737e-04         0.000000        0.000000
#
#    param_classifier__C param_preprocessor__cat__imputer__strategy  \
# 0                  0.1                              most_frequent
# 4                  0.1                                   constant
# 8                  1.0                              most_frequent
# 12                 1.0                                   constant
# 17                  10                              most_frequent
# 21                  10                                   constant
# 16                  10                              most_frequent
# 9                  1.0                              most_frequent
# 20                  10                                   constant
# 24                 100                              most_frequent
# 25                 100                              most_frequent
# 28                 100                                   constant
# 29                 100                                   constant
# 13                 1.0                                   constant
# 1                  0.1                              most_frequent
# 5                  0.1                                   constant
# 2                  0.1                              most_frequent
# 3                  0.1                              most_frequent
# 6                  0.1                                   constant
# 7                  0.1                                   constant
# 10                 1.0                              most_frequent
# 11                 1.0                              most_frequent
# 14                 1.0                                   constant
# 15                 1.0                                   constant
# 18                  10                              most_frequent
# 19                  10                              most_frequent
# 22                  10                                   constant
# 23                  10                                   constant
# 26                 100                              most_frequent
# 27                 100                              most_frequent
# 30                 100                                   constant
# 31                 100                                   constant
#
#    param_preprocessor__num__imputer__strategy param_preprocessor__num__scaler  \
# 0                                        mean                StandardScaler()
# 4                                        mean                StandardScaler()
# 8                                        mean                StandardScaler()
# 12                                       mean                StandardScaler()
# 17                                       mean                  MinMaxScaler()
# 21                                       mean                  MinMaxScaler()
# 16                                       mean                StandardScaler()
# 9                                        mean                  MinMaxScaler()
# 20                                       mean                StandardScaler()
# 24                                       mean                StandardScaler()
# 25                                       mean                  MinMaxScaler()
# 28                                       mean                StandardScaler()
# 29                                       mean                  MinMaxScaler()
# 13                                       mean                  MinMaxScaler()
# 1                                        mean                  MinMaxScaler()
# 5                                        mean                  MinMaxScaler()
# 2                                     meadian                StandardScaler()
# 3                                     meadian                  MinMaxScaler()
# 6                                     meadian                StandardScaler()
# 7                                     meadian                  MinMaxScaler()
# 10                                    meadian                StandardScaler()
# 11                                    meadian                  MinMaxScaler()
# 14                                    meadian                StandardScaler()
# 15                                    meadian                  MinMaxScaler()
# 18                                    meadian                StandardScaler()
# 19                                    meadian                  MinMaxScaler()
# 22                                    meadian                StandardScaler()
# 23                                    meadian                  MinMaxScaler()
# 26                                    meadian                StandardScaler()
# 27                                    meadian                  MinMaxScaler()
# 30                                    meadian                StandardScaler()
# 31                                    meadian                  MinMaxScaler()
#
#                                                params  split0_test_score  ...  \
# 0   {'classifier__C': 0.1, 'preprocessor__cat__imp...           0.791667  ...
# 4   {'classifier__C': 0.1, 'preprocessor__cat__imp...           0.791667  ...
# 8   {'classifier__C': 1.0, 'preprocessor__cat__imp...           0.791667  ...
# 12  {'classifier__C': 1.0, 'preprocessor__cat__imp...           0.791667  ...
# 17  {'classifier__C': 10, 'preprocessor__cat__impu...           0.791667  ...
# 21  {'classifier__C': 10, 'preprocessor__cat__impu...           0.777778  ...
# 16  {'classifier__C': 10, 'preprocessor__cat__impu...           0.791667  ...
# 9   {'classifier__C': 1.0, 'preprocessor__cat__imp...           0.805556  ...
# 20  {'classifier__C': 10, 'preprocessor__cat__impu...           0.777778  ...
# 24  {'classifier__C': 100, 'preprocessor__cat__imp...           0.777778  ...
# 25  {'classifier__C': 100, 'preprocessor__cat__imp...           0.777778  ...
# 28  {'classifier__C': 100, 'preprocessor__cat__imp...           0.777778  ...
# 29  {'classifier__C': 100, 'preprocessor__cat__imp...           0.777778  ...
# 13  {'classifier__C': 1.0, 'preprocessor__cat__imp...           0.805556  ...
# 1   {'classifier__C': 0.1, 'preprocessor__cat__imp...           0.791667  ...
# 5   {'classifier__C': 0.1, 'preprocessor__cat__imp...           0.791667  ...
# 2   {'classifier__C': 0.1, 'preprocessor__cat__imp...                NaN  ...
# 3   {'classifier__C': 0.1, 'preprocessor__cat__imp...                NaN  ...
# 6   {'classifier__C': 0.1, 'preprocessor__cat__imp...                NaN  ...
# 7   {'classifier__C': 0.1, 'preprocessor__cat__imp...                NaN  ...
# 10  {'classifier__C': 1.0, 'preprocessor__cat__imp...                NaN  ...
# 11  {'classifier__C': 1.0, 'preprocessor__cat__imp...                NaN  ...
# 14  {'classifier__C': 1.0, 'preprocessor__cat__imp...                NaN  ...
# 15  {'classifier__C': 1.0, 'preprocessor__cat__imp...                NaN  ...
# 18  {'classifier__C': 10, 'preprocessor__cat__impu...                NaN  ...
# 19  {'classifier__C': 10, 'preprocessor__cat__impu...                NaN  ...
# 22  {'classifier__C': 10, 'preprocessor__cat__impu...                NaN  ...
# 23  {'classifier__C': 10, 'preprocessor__cat__impu...                NaN  ...
# 26  {'classifier__C': 100, 'preprocessor__cat__imp...                NaN  ...
# 27  {'classifier__C': 100, 'preprocessor__cat__imp...                NaN  ...
# 30  {'classifier__C': 100, 'preprocessor__cat__imp...                NaN  ...
# 31  {'classifier__C': 100, 'preprocessor__cat__imp...                NaN  ...
#
#     split3_test_score  split4_test_score  split5_test_score  \
# 0            0.845070           0.788732           0.816901
# 4            0.830986           0.788732           0.816901
# 8            0.816901           0.774648           0.816901
# 12           0.816901           0.774648           0.816901
# 17           0.816901           0.774648           0.830986
# 21           0.816901           0.774648           0.830986
# 16           0.802817           0.774648           0.830986
# 9            0.816901           0.788732           0.802817
# 20           0.802817           0.774648           0.830986
# 24           0.802817           0.774648           0.830986
# 25           0.802817           0.774648           0.830986
# 28           0.802817           0.774648           0.830986
# 29           0.802817           0.774648           0.830986
# 13           0.816901           0.774648           0.802817
# 1            0.816901           0.774648           0.830986
# 5            0.816901           0.774648           0.830986
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
# 26                NaN                NaN                NaN
# 27                NaN                NaN                NaN
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
#
#     split6_test_score  split7_test_score  split8_test_score  \
# 0            0.816901           0.774648           0.774648
# 4            0.816901           0.774648           0.774648
# 8            0.788732           0.774648           0.774648
# 12           0.788732           0.774648           0.774648
# 17           0.788732           0.774648           0.760563
# 21           0.788732           0.774648           0.760563
# 16           0.788732           0.774648           0.760563
# 9            0.802817           0.760563           0.774648
# 20           0.788732           0.774648           0.760563
# 24           0.788732           0.774648           0.760563
# 25           0.788732           0.774648           0.760563
# 28           0.788732           0.774648           0.760563
# 29           0.788732           0.774648           0.760563
# 13           0.802817           0.760563           0.774648
# 1            0.802817           0.746479           0.760563
# 5            0.802817           0.746479           0.760563
# 2                 NaN                NaN                NaN
# 3                 NaN                NaN                NaN
# 6                 NaN                NaN                NaN
# 7                 NaN                NaN                NaN
# 10                NaN                NaN                NaN
# 11                NaN                NaN                NaN
# 14                NaN                NaN                NaN
# 15                NaN                NaN                NaN
# 18                NaN                NaN                NaN
# 19                NaN                NaN                NaN
# 22                NaN                NaN                NaN
# 23                NaN                NaN                NaN
# 26                NaN                NaN                NaN
# 27                NaN                NaN                NaN
# 30                NaN                NaN                NaN
# 31                NaN                NaN                NaN
#
#     split9_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.816901         0.811718        0.033025                1
# 4            0.816901         0.810309        0.031852                2
# 8            0.830986         0.806084        0.033459                3
# 12           0.830986         0.806084        0.033459                3
# 17           0.830986         0.806084        0.035752                5
# 21           0.830986         0.804695        0.036546                6
# 16           0.830986         0.804675        0.035575                7
# 9            0.802817         0.804656        0.032183                8
# 20           0.830986         0.803286        0.036319                9
# 24           0.830986         0.803286        0.036319                9
# 25           0.830986         0.803286        0.036319                9
# 28           0.830986         0.803286        0.036319                9
# 29           0.830986         0.803286        0.036319                9
# 13           0.802817         0.803247        0.033143               14
# 1            0.802817         0.799081        0.031824               15
# 5            0.802817         0.799081        0.031824               15
# 2                 NaN              NaN             NaN               17
# 3                 NaN              NaN             NaN               17
# 6                 NaN              NaN             NaN               17
# 7                 NaN              NaN             NaN               17
# 10                NaN              NaN             NaN               17
# 11                NaN              NaN             NaN               17
# 14                NaN              NaN             NaN               17
# 15                NaN              NaN             NaN               17
# 18                NaN              NaN             NaN               17
# 19                NaN              NaN             NaN               17
# 22                NaN              NaN             NaN               17
# 23                NaN              NaN             NaN               17
# 26                NaN              NaN             NaN               17
# 27                NaN              NaN             NaN               17
# 30                NaN              NaN             NaN               17
# 31                NaN              NaN             NaN               17
#
# [32 rows x 22 columns]

# %%
cv_results[['param_classifier__C','param_preprocessor__cat__imputer__strategy','param_preprocessor__num__imputer__strategy','param_preprocessor__num__scaler','mean_test_score']]
# Out:
#    param_classifier__C param_preprocessor__cat__imputer__strategy  \
# 0                  0.1                              most_frequent
# 4                  0.1                                   constant
# 8                  1.0                              most_frequent
# 12                 1.0                                   constant
# 17                  10                              most_frequent
# 21                  10                                   constant
# 16                  10                              most_frequent
# 9                  1.0                              most_frequent
# 20                  10                                   constant
# 24                 100                              most_frequent
# 25                 100                              most_frequent
# 28                 100                                   constant
# 29                 100                                   constant
# 13                 1.0                                   constant
# 1                  0.1                              most_frequent
# 5                  0.1                                   constant
# 2                  0.1                              most_frequent
# 3                  0.1                              most_frequent
# 6                  0.1                                   constant
# 7                  0.1                                   constant
# 10                 1.0                              most_frequent
# 11                 1.0                              most_frequent
# 14                 1.0                                   constant
# 15                 1.0                                   constant
# 18                  10                              most_frequent
# 19                  10                              most_frequent
# 22                  10                                   constant
# 23                  10                                   constant
# 26                 100                              most_frequent
# 27                 100                              most_frequent
# 30                 100                                   constant
# 31                 100                                   constant
#
#    param_preprocessor__num__imputer__strategy param_preprocessor__num__scaler  \
# 0                                        mean                StandardScaler()
# 4                                        mean                StandardScaler()
# 8                                        mean                StandardScaler()
# 12                                       mean                StandardScaler()
# 17                                       mean                  MinMaxScaler()
# 21                                       mean                  MinMaxScaler()
# 16                                       mean                StandardScaler()
# 9                                        mean                  MinMaxScaler()
# 20                                       mean                StandardScaler()
# 24                                       mean                StandardScaler()
# 25                                       mean                  MinMaxScaler()
# 28                                       mean                StandardScaler()
# 29                                       mean                  MinMaxScaler()
# 13                                       mean                  MinMaxScaler()
# 1                                        mean                  MinMaxScaler()
# 5                                        mean                  MinMaxScaler()
# 2                                     meadian                StandardScaler()
# 3                                     meadian                  MinMaxScaler()
# 6                                     meadian                StandardScaler()
# 7                                     meadian                  MinMaxScaler()
# 10                                    meadian                StandardScaler()
# 11                                    meadian                  MinMaxScaler()
# 14                                    meadian                StandardScaler()
# 15                                    meadian                  MinMaxScaler()
# 18                                    meadian                StandardScaler()
# 19                                    meadian                  MinMaxScaler()
# 22                                    meadian                StandardScaler()
# 23                                    meadian                  MinMaxScaler()
# 26                                    meadian                StandardScaler()
# 27                                    meadian                  MinMaxScaler()
# 30                                    meadian                StandardScaler()
# 31                                    meadian                  MinMaxScaler()
#
#     mean_test_score
# 0          0.811718
# 4          0.810309
# 8          0.806084
# 12         0.806084
# 17         0.806084
# 21         0.804695
# 16         0.804675
# 9          0.804656
# 20         0.803286
# 24         0.803286
# 25         0.803286
# 28         0.803286
# 29         0.803286
# 13         0.803247
# 1          0.799081
# 5          0.799081
# 2               NaN
# 3               NaN
# 6               NaN
# 7               NaN
# 10              NaN
# 11              NaN
# 14              NaN
# 15              NaN
# 18              NaN
# 19              NaN
# 22              NaN
# 23              NaN
# 26              NaN
# 27              NaN
# 30              NaN
# 31              NaN
