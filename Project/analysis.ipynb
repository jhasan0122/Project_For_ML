# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('house-prices/train.csv')
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.iloc[:10,:10]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities
# 0         Lvl    AllPub
# 1         Lvl    AllPub
# 2         Lvl    AllPub
# 3         Lvl    AllPub
# 4         Lvl    AllPub
# 5         Lvl    AllPub
# ...

# %%
df.iloc[:10,:20]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl      CollgCr       Norm
# ...

# %%
df.iloc[:10,:30]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... YearRemodAdd RoofStyle RoofMatl Exterior1st  \
# 0         Lvl    AllPub  ...         2003     Gable  CompShg     VinylSd
# ...

# %%
df.iloc[:10,:40]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... BsmtQual BsmtCond BsmtExposure BsmtFinType1  \
# 0         Lvl    AllPub  ...       Gd       TA           No          GLQ
# ...

# %%
df.iloc[:10,:50]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... HeatingQC CentralAir Electrical 1stFlrSF  \
# 0         Lvl    AllPub  ...        Ex          Y      SBrkr      856
# ...

# %%
df.iloc[:10,:60]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... HalfBath BedroomAbvGr KitchenAbvGr KitchenQual  \
# 0         Lvl    AllPub  ...        1            3            1          Gd
# ...

# %%
df.iloc[:10,:70]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... GarageFinish GarageCars GarageArea GarageQual  \
# 0         Lvl    AllPub  ...          RFn          2        548         TA
# ...

# %%
df.iloc[:10,:81]
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
# 5   6          50       RL         85.0    14115   Pave   NaN      IR1
# 6   7          20       RL         75.0    10084   Pave   NaN      Reg
# 7   8          60       RL          NaN    10382   Pave   NaN      IR1
# 8   9          50       RM         51.0     6120   Pave   NaN      Reg
# 9  10         190       RL         50.0     7420   Pave   NaN      Reg
#
#   LandContour Utilities  ... PoolArea PoolQC  Fence MiscFeature MiscVal  \
# 0         Lvl    AllPub  ...        0    NaN    NaN         NaN       0
# ...

# %%
df = df[['MSZoning', 'LotFrontage', 'LotArea', 'BldgType', 'OverallQual', 'OverallCond', 'YearBuilt', 'Foundation', 'BsmtCond', 'TotalBsmtSF', '1stFlrSF' ,'2ndFlrSF' , 'GrLivArea' , 'KitchenQual' ,'TotRmsAbvGrd' , 'GarageType' , 'GarageCars' , 'GarageArea' , 'GarageQual' , 'GarageCond' , 'PoolArea' , 'PoolQC' , 'Fence' , 'MiscFeature', 'MiscVal' , 'SaleType' ,  'SaleCondition' ,'RoofStyle', 'RoofMatl' , 'Exterior1st', 'Exterior2nd' , 'ExterQual', 'ExterCond' , 'BsmtQual', 'CentralAir', 'YrSold', 'SalePrice']]
df
# Out:
#      MSZoning  LotFrontage  LotArea BldgType  OverallQual  OverallCond  \
# 0          RL         65.0     8450     1Fam            7            5
# 1          RL         80.0     9600     1Fam            6            8
# 2          RL         68.0    11250     1Fam            7            5
# 3          RL         60.0     9550     1Fam            7            5
# 4          RL         84.0    14260     1Fam            8            5
# ...       ...          ...      ...      ...          ...          ...
# 1455       RL         62.0     7917     1Fam            6            5
# 1456       RL         85.0    13175     1Fam            6            6
# 1457       RL         66.0     9042     1Fam            7            9
# 1458       RL         68.0     9717     1Fam            5            6
# 1459       RL         75.0     9937     1Fam            5            6
#
#       YearBuilt Foundation BsmtCond  TotalBsmtSF  ...  RoofStyle  RoofMatl  \
# ...

# %%
np.round(df.isnull().mean()*100,2)
# Out:
# MSZoning          0.00
# LotFrontage      17.74
# LotArea           0.00
# BldgType          0.00
# OverallQual       0.00
# OverallCond       0.00
# YearBuilt         0.00
# Foundation        0.00
# BsmtCond          2.53
# TotalBsmtSF       0.00
# 1stFlrSF          0.00
# 2ndFlrSF          0.00
# GrLivArea         0.00
# KitchenQual       0.00
# TotRmsAbvGrd      0.00
# GarageType        5.55
# GarageCars        0.00
# GarageArea        0.00
# GarageQual        5.55
# GarageCond        5.55
# PoolArea          0.00
# PoolQC           99.52
# Fence            80.75
# MiscFeature      96.30
# MiscVal           0.00
# SaleType          0.00
# SaleCondition     0.00
# RoofStyle         0.00
# RoofMatl          0.00
# Exterior1st       0.00
# Exterior2nd       0.00
# ExterQual         0.00
# ExterCond         0.00
# BsmtQual          2.53
# CentralAir        0.00
# YrSold            0.00
# SalePrice         0.00
# dtype: float64

# %%
df.drop(columns=['PoolQC','Fence','MiscFeature'],inplace=True)
# Out:
# C:\Users\HP TECHNOLOGY\AppData\Local\Temp\ipykernel_3208\4177526432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['PoolQC','Fence','MiscFeature'],inplace=True)

# %%
df
# Out:
#      MSZoning  LotFrontage  LotArea BldgType  OverallQual  OverallCond  \
# 0          RL         65.0     8450     1Fam            7            5
# 1          RL         80.0     9600     1Fam            6            8
# 2          RL         68.0    11250     1Fam            7            5
# 3          RL         60.0     9550     1Fam            7            5
# 4          RL         84.0    14260     1Fam            8            5
# ...       ...          ...      ...      ...          ...          ...
# 1455       RL         62.0     7917     1Fam            6            5
# 1456       RL         85.0    13175     1Fam            6            6
# 1457       RL         66.0     9042     1Fam            7            9
# 1458       RL         68.0     9717     1Fam            5            6
# 1459       RL         75.0     9937     1Fam            5            6
#
#       YearBuilt Foundation BsmtCond  TotalBsmtSF  ...  RoofStyle  RoofMatl  \
# ...

# %%
np.round(df.isnull().mean()*100,2)
# Out:
# MSZoning          0.00
# LotFrontage      17.74
# LotArea           0.00
# BldgType          0.00
# OverallQual       0.00
# OverallCond       0.00
# YearBuilt         0.00
# Foundation        0.00
# BsmtCond          2.53
# TotalBsmtSF       0.00
# 1stFlrSF          0.00
# 2ndFlrSF          0.00
# GrLivArea         0.00
# KitchenQual       0.00
# TotRmsAbvGrd      0.00
# GarageType        5.55
# GarageCars        0.00
# GarageArea        0.00
# GarageQual        5.55
# GarageCond        5.55
# PoolArea          0.00
# MiscVal           0.00
# SaleType          0.00
# SaleCondition     0.00
# RoofStyle         0.00
# RoofMatl          0.00
# Exterior1st       0.00
# Exterior2nd       0.00
# ExterQual         0.00
# ExterCond         0.00
# BsmtQual          2.53
# CentralAir        0.00
# YrSold            0.00
# SalePrice         0.00
# dtype: float64

# %%
cat_encoded = ['OverallQual', 'OverallCond',]

categoricalColumns = ['MSZoning', 'BldgType',  'Foundation', 'BsmtCond',   'KitchenQual' , 'GarageType' ,  'GarageQual' , 'GarageCond' ,  'SaleType' ,  'SaleCondition' ,'RoofStyle', 'RoofMatl' , 'Exterior1st', 'Exterior2nd' , 'ExterQual', 'ExterCond' , 'BsmtQual', 'CentralAir']


numaricalColumns = ['LotFrontage', 'LotArea','YearBuilt','YrSold', 'TotalBsmtSF', '1stFlrSF' ,'2ndFlrSF' ,'GrLivArea' ,'TotRmsAbvGrd' , 'GarageCars' , 'GarageArea' ,'PoolArea' , 'MiscVal' ,'SalePrice']

# %%
df[categoricalColumns]
# Out:
#      MSZoning BldgType Foundation BsmtCond KitchenQual GarageType GarageQual  \
# 0          RL     1Fam      PConc       TA          Gd     Attchd         TA
# 1          RL     1Fam     CBlock       TA          TA     Attchd         TA
# 2          RL     1Fam      PConc       TA          Gd     Attchd         TA
# 3          RL     1Fam     BrkTil       Gd          Gd     Detchd         TA
# 4          RL     1Fam      PConc       TA          Gd     Attchd         TA
# ...       ...      ...        ...      ...         ...        ...        ...
# 1455       RL     1Fam      PConc       TA          TA     Attchd         TA
# 1456       RL     1Fam     CBlock       TA          TA     Attchd         TA
# 1457       RL     1Fam      Stone       Gd          Gd     Attchd         TA
# 1458       RL     1Fam     CBlock       TA          Gd     Attchd         TA
# 1459       RL     1Fam     CBlock       TA          TA     Attchd         TA
#
# ...

# %%
categoricalColumns = ['MSZoning', 'BldgType',  'Foundation', 'BsmtCond',   'KitchenQual' , 'GarageType' ,  'GarageQual' , 'GarageCond' ,  'SaleType' ,  'SaleCondition' ,'RoofStyle', 'RoofMatl' , 'Exterior1st', 'Exterior2nd' , 'ExterQual', 'ExterCond' , 'BsmtQual', 'CentralAir']

cat_impute = ['BsmtCond','GarageType','GarageQual' , 'GarageCond' , 'BsmtQual']

ordinalColumns = ['BsmtCond', 'KitchenQual' ,'GarageQual' , 'GarageCond' ,'ExterQual', 'ExterCond' , 'BsmtQual']
oneHotColumns = ['MSZoning', 'BldgType',  'Foundation',    'GarageType' ,    'SaleType' ,  'SaleCondition' ,'RoofStyle', 'RoofMatl' , 'Exterior1st', 'Exterior2nd' ,  'CentralAir']

# %%
numaricalColumns = ['LotFrontage', 'OverallQual', 'OverallCond', 'LotArea','YearBuilt','YrSold', 'TotalBsmtSF', '1stFlrSF' ,'2ndFlrSF' ,'GrLivArea' ,'TotRmsAbvGrd' , 'GarageCars' , 'GarageArea' ,'PoolArea' , 'MiscVal' ,'SalePrice']

num_impute = ['LotFrontage']

# %%
np.round(df.isnull().mean()*100,2)
# Out:
# MSZoning          0.00
# LotFrontage      17.74
# LotArea           0.00
# BldgType          0.00
# OverallQual       0.00
# OverallCond       0.00
# YearBuilt         0.00
# Foundation        0.00
# BsmtCond          2.53
# TotalBsmtSF       0.00
# 1stFlrSF          0.00
# 2ndFlrSF          0.00
# GrLivArea         0.00
# KitchenQual       0.00
# TotRmsAbvGrd      0.00
# GarageType        5.55
# GarageCars        0.00
# GarageArea        0.00
# GarageQual        5.55
# GarageCond        5.55
# PoolArea          0.00
# MiscVal           0.00
# SaleType          0.00
# SaleCondition     0.00
# RoofStyle         0.00
# RoofMatl          0.00
# Exterior1st       0.00
# Exterior2nd       0.00
# ExterQual         0.00
# ExterCond         0.00
# BsmtQual          2.53
# CentralAir        0.00
# YrSold            0.00
# SalePrice         0.00
# dtype: float64

# %%
for col in categoricalColumns:
    print(df[col].value_counts())
    print("-----------------------------------")
# Out:
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: count, dtype: int64
# -----------------------------------
# BldgType
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# Twnhs       43
# 2fmCon      31
# Name: count, dtype: int64
# -----------------------------------
# Foundation
# PConc     647
# CBlock    634
# BrkTil    146
# Slab       24
# Stone       6
# Wood        3
# Name: count, dtype: int64
# -----------------------------------
# BsmtCond
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: count, dtype: int64
# -----------------------------------
# KitchenQual
# TA    735
# Gd    586
# Ex    100
# Fa     39
# Name: count, dtype: int64
# -----------------------------------
# GarageType
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: count, dtype: int64
# -----------------------------------
# GarageQual
# TA    1311
# Fa      48
# Gd      14
# ...

# %%
for col in categoricalColumns:
    print(df[col].nunique(),col)
# Out:
# 5 MSZoning
# 5 BldgType
# 6 Foundation
# 4 BsmtCond
# 4 KitchenQual
# 6 GarageType
# 5 GarageQual
# 5 GarageCond
# 9 SaleType
# 6 SaleCondition
# 6 RoofStyle
# 8 RoofMatl
# 15 Exterior1st
# 16 Exterior2nd
# 4 ExterQual
# 5 ExterCond
# 4 BsmtQual
# 2 CentralAir

# %%
df[numaricalColumns]
# Out:
#       LotFrontage  OverallQual  OverallCond  LotArea  YearBuilt  YrSold  \
# 0            65.0            7            5     8450       2003    2008
# 1            80.0            6            8     9600       1976    2007
# 2            68.0            7            5    11250       2001    2008
# 3            60.0            7            5     9550       1915    2006
# 4            84.0            8            5    14260       2000    2008
# ...           ...          ...          ...      ...        ...     ...
# 1455         62.0            6            5     7917       1999    2007
# 1456         85.0            6            6    13175       1978    2010
# 1457         66.0            7            9     9042       1941    2010
# 1458         68.0            5            6     9717       1950    2010
# 1459         75.0            5            6     9937       1965    2008
#
#       TotalBsmtSF  1stFlrSF  2ndFlrSF  GrLivArea  TotRmsAbvGrd  GarageCars  \
# ...

# %%
df['YearBuilt'] = pd.to_datetime(df['YearBuilt']).dt.year
df['YrSold'] = pd.to_datetime(df['YrSold']).dt.year
# Out:
# C:\Users\HP TECHNOLOGY\AppData\Local\Temp\ipykernel_3208\4175498385.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['YearBuilt'] = pd.to_datetime(df['YearBuilt']).dt.year
# C:\Users\HP TECHNOLOGY\AppData\Local\Temp\ipykernel_3208\4175498385.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['YrSold'] = pd.to_datetime(df['YrSold']).dt.year

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 34 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   MSZoning       1460 non-null   object
#  1   LotFrontage    1201 non-null   float64
#  2   LotArea        1460 non-null   int64
#  3   BldgType       1460 non-null   object
#  4   OverallQual    1460 non-null   int64
#  5   OverallCond    1460 non-null   int64
#  6   YearBuilt      1460 non-null   int32
#  7   Foundation     1460 non-null   object
#  8   BsmtCond       1423 non-null   object
#  9   TotalBsmtSF    1460 non-null   int64
#  10  1stFlrSF       1460 non-null   int64
#  11  2ndFlrSF       1460 non-null   int64
#  12  GrLivArea      1460 non-null   int64
#  13  KitchenQual    1460 non-null   object
#  14  TotRmsAbvGrd   1460 non-null   int64
#  15  GarageType     1379 non-null   object
#  16  GarageCars     1460 non-null   int64
# ...
