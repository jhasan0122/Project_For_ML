# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.impute import SimpleImputer

from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, OrdinalEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('house-prices/train.csv',usecols=['MSZoning', 'LotFrontage', 'LotArea', 'BldgType', 'OverallQual', 'OverallCond', 'YearBuilt', 'Foundation', 'BsmtCond', 'TotalBsmtSF', '1stFlrSF' ,'2ndFlrSF' , 'GrLivArea' , 'KitchenQual' ,'TotRmsAbvGrd' , 'GarageType' , 'GarageCars' , 'GarageArea' , 'GarageQual' , 'GarageCond' , 'PoolArea' ,  'MiscVal' , 'SaleType' ,  'SaleCondition' ,'RoofStyle', 'RoofMatl' , 'Exterior1st', 'Exterior2nd' , 'ExterQual', 'ExterCond' , 'BsmtQual', 'CentralAir', 'YrSold', 'SalePrice'])
df
# Out:
#      MSZoning  LotFrontage  LotArea BldgType  OverallQual  OverallCond  \
# 0          RL         65.0     8450     1Fam            7            5
# 1          RL         80.0     9600     1Fam            6            8
# 2          RL         68.0    11250     1Fam            7            5
# 3          RL         60.0     9550     1Fam            7            5
# 4          RL         84.0    14260     1Fam            8            5
# ...       ...          ...      ...      ...          ...          ...
# 1455       RL         62.0     7917     1Fam            6            5
# 1456       RL         85.0    13175     1Fam            6            6
# 1457       RL         66.0     9042     1Fam            7            9
# 1458       RL         68.0     9717     1Fam            5            6
# 1459       RL         75.0     9937     1Fam            5            6
#
#       YearBuilt RoofStyle RoofMatl Exterior1st  ... GarageCars GarageArea  \
# 0          2003     Gable  CompShg     VinylSd  ...          2        548
# 1          1976     Gable  CompShg     MetalSd  ...          2        460
# 2          2001     Gable  CompShg     VinylSd  ...          2        608
# 3          1915     Gable  CompShg     Wd Sdng  ...          3        642
# 4          2000     Gable  CompShg     VinylSd  ...          3        836
# ...         ...       ...      ...         ...  ...        ...        ...
# 1455       1999     Gable  CompShg     VinylSd  ...          2        460
# 1456       1978     Gable  CompShg     Plywood  ...          2        500
# 1457       1941     Gable  CompShg     CemntBd  ...          1        252
# 1458       1950       Hip  CompShg     MetalSd  ...          1        240
# 1459       1965     Gable  CompShg     HdBoard  ...          1        276
#
#      GarageQual GarageCond PoolArea MiscVal  YrSold SaleType  SaleCondition  \
# 0            TA         TA        0       0    2008       WD         Normal
# 1            TA         TA        0       0    2007       WD         Normal
# 2            TA         TA        0       0    2008       WD         Normal
# 3            TA         TA        0       0    2006       WD        Abnorml
# 4            TA         TA        0       0    2008       WD         Normal
# ...         ...        ...      ...     ...     ...      ...            ...
# 1455         TA         TA        0       0    2007       WD         Normal
# 1456         TA         TA        0       0    2010       WD         Normal
# 1457         TA         TA        0    2500    2010       WD         Normal
# 1458         TA         TA        0       0    2010       WD         Normal
# 1459         TA         TA        0       0    2008       WD         Normal
#
#       SalePrice
# 0        208500
# 1        181500
# 2        223500
# 3        140000
# 4        250000
# ...         ...
# 1455     175000
# 1456     210000
# 1457     266500
# 1458     142125
# 1459     147500
#
# [1460 rows x 34 columns]

# %%
df['YearBuilt'] = pd.to_datetime(df['YearBuilt']).dt.year
df['YrSold'] = pd.to_datetime(df['YrSold']).dt.year

# %%
removable_col = [x for x in df.columns if (df[x].isnull().sum() > 0)]
removable_col
# Out:
# ['LotFrontage',
#  'BsmtQual',
#  'BsmtCond',
#  'GarageType',
#  'GarageQual',
#  'GarageCond']

# %%
# df = df[removable_col].dropna()

# %%
X = df.iloc[:,:-1]
y = df.iloc[:,-1]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=46)

# %%
X_train
# Out:
#      MSZoning  LotFrontage  LotArea BldgType  OverallQual  OverallCond  \
# 358        RL         92.0     6930     1Fam            5            4
# 1423       RL          NaN    19690     1Fam            6            7
# 1073       RL         75.0     7950     1Fam            6            6
# 332        RL         85.0    10655     1Fam            8            5
# 225        RM         21.0     1680    Twnhs            5            5
# ...       ...          ...      ...      ...          ...          ...
# 403        RL         93.0    12090     1Fam            8            5
# 442        RM         52.0     6240     1Fam            5            7
# 1396       RL          NaN    57200     1Fam            5            5
# 837        RM         21.0     1680    Twnhs            6            5
# 1213       RL          NaN    10246     1Fam            4            9
#
#       YearBuilt RoofStyle RoofMatl Exterior1st  ... GarageType GarageCars  \
# 358        1970       Hip  CompShg     Wd Sdng  ...    BuiltIn          1
# 1423       1970      Flat  Tar&Grv     Plywood  ...     Attchd          2
# 1073       1970       Hip  CompShg     HdBoard  ...     Attchd          2
# 332        1970     Gable  CompShg     VinylSd  ...     Attchd          3
# 225        1970     Gable  CompShg     HdBoard  ...     Detchd          1
# ...         ...       ...      ...         ...  ...        ...        ...
# 403        1970       Hip  CompShg     VinylSd  ...    BuiltIn          2
# 442        1970     Gable  CompShg     MetalSd  ...     Detchd          2
# 1396       1970     Gable  CompShg     Wd Sdng  ...     Detchd          2
# 837        1970     Gable  CompShg     HdBoard  ...     Detchd          1
# 1213       1970     Gable  CompShg     VinylSd  ...     Attchd          1
#
#      GarageArea GarageQual GarageCond PoolArea  MiscVal YrSold  SaleType  \
# 358         288         TA         TA        0        0   1970        WD
# 1423        432         Gd         Gd      738        0   1970        WD
# 1073        440         TA         TA        0        0   1970        WD
# 332         880         TA         TA        0        0   1970        WD
# 225         280         TA         TA        0        0   1970       COD
# ...         ...        ...        ...      ...      ...    ...       ...
# 403         420         TA         TA        0        0   1970        WD
# 442         360         TA         TA        0        0   1970        WD
# 1396        572         TA         TA        0        0   1970        WD
# 837         264         TA         TA        0        0   1970        WD
# 1213        364         TA         TA        0        0   1970        WD
#
#       SaleCondition
# 358         Abnorml
# 1423         Alloca
# 1073         Normal
# 332          Normal
# 225         Abnorml
# ...             ...
# 403         Abnorml
# 442          Normal
# 1396         Normal
# 837          Normal
# 1213         Normal
#
# [1022 rows x 33 columns]

# %%
categoricalColumns = ['MSZoning', 'BldgType',  'Foundation', 'BsmtCond',   'KitchenQual' , 'GarageType' ,  'GarageQual' , 'GarageCond' ,  'SaleType' ,  'SaleCondition' ,'RoofStyle', 'RoofMatl' , 'Exterior1st', 'Exterior2nd' , 'ExterQual', 'ExterCond' , 'BsmtQual', 'CentralAir']

cat_impute = ['BsmtCond','GarageType','GarageQual' , 'GarageCond' , 'BsmtQual']

ordinalColumns = ['BsmtCond', 'KitchenQual' ,'GarageQual' , 'GarageCond' ,'ExterQual', 'ExterCond' , 'BsmtQual']
oneHotColumns = ['MSZoning', 'BldgType',  'Foundation',    'GarageType' ,    'SaleType' ,  'SaleCondition' ,'RoofStyle', 'RoofMatl' , 'Exterior1st', 'Exterior2nd' ,  'CentralAir']

# %%
numaricalColumns = ['LotFrontage','OverallQual', 'OverallCond', 'LotArea','YearBuilt','YrSold', 'TotalBsmtSF', '1stFlrSF' ,'2ndFlrSF' ,'GrLivArea' ,'TotRmsAbvGrd' , 'GarageCars' , 'GarageArea' ,'PoolArea' , 'MiscVal']

num_std= ['OverallQual', 'OverallCond', 'LotArea','YearBuilt','YrSold', 'TotalBsmtSF', '1stFlrSF' ,'2ndFlrSF' ,'GrLivArea' ,'TotRmsAbvGrd' , 'GarageCars' , 'GarageArea' ,'PoolArea' , 'MiscVal']

num_im_st = ['LotFrontage']

# %%
X_train.columns
# Out:
# Index(['MSZoning', 'LotFrontage', 'LotArea', 'BldgType', 'OverallQual',
#        'OverallCond', 'YearBuilt', 'RoofStyle', 'RoofMatl', 'Exterior1st',
#        'Exterior2nd', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'TotalBsmtSF', 'CentralAir', '1stFlrSF', '2ndFlrSF',
#        'GrLivArea', 'KitchenQual', 'TotRmsAbvGrd', 'GarageType', 'GarageCars',
#        'GarageArea', 'GarageQual', 'GarageCond', 'PoolArea', 'MiscVal',
#        'YrSold', 'SaleType', 'SaleCondition'],
#       dtype='object')

# %%
numaricalColumns
# Out:
# ['LotFrontage',
#  'OverallQual',
#  'OverallCond',
#  'LotArea',
#  'YearBuilt',
#  'YrSold',
#  'TotalBsmtSF',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'GrLivArea',
#  'TotRmsAbvGrd',
#  'GarageCars',
#  'GarageArea',
#  'PoolArea',
#  'MiscVal']

# %% [markdown]
# # Impute and Scalling

# %%
numerical_transfromer = Pipeline(
    steps=[
        ("num_imputer",SimpleImputer(strategy='mean')),
        ("numScaler",StandardScaler())
    ]
)


categorical_ordi_transformer = Pipeline(
    steps=[
        ("cat_imputer1",SimpleImputer(strategy='most_frequent')),
        ("ord_encod",OrdinalEncoder(categories=[
            ['NA',	'Po' ,'Fa' ,'TA' ,'Gd','Ex'],
            ['Po' ,'Fa' ,'TA' ,'Gd','Ex'],
            ['NA',	'Po' ,'Fa' ,'TA' ,'Gd','Ex'],
            ['NA',	'Po' ,'Fa' ,'TA' ,'Gd','Ex'],
            ['Po' ,'Fa' ,'TA' ,'Gd','Ex'],
            ['Po' ,'Fa' ,'TA' ,'Gd','Ex'],
            ['NA',	'Po' ,'Fa' ,'TA' ,'Gd','Ex']
        ]))
    ]
)

categorical_oneHot_transformer = Pipeline(
    steps=[
        ("cat_imputer1",SimpleImputer(strategy='most_frequent')),
        ("ohe_encod",OneHotEncoder(handle_unknown='ignore'))
    ]
)

# %% [markdown]
# # Using transformer

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ('imp_stand',numerical_transfromer,numaricalColumns),
        ('cat_ordi',categorical_ordi_transformer,ordinalColumns),
        ('cat_oneHot',categorical_oneHot_transformer,oneHotColumns)
    ],remainder='passthrough'    
)

# %%
# clf = Pipeline(
#     steps=[
#         ('preprocessor',preprocessor),
#         ('classifier',LinearRegression())
#     ]
# )

# %%
# clf.fit(X_train,X_test)
X_train_trf = preprocessor.fit_transform(X_train)
X_test_trf = preprocessor.transform(X_test)

# %%
from sklearn.decomposition import PCA

pca = PCA(n_components=10)

X_train_trf = pca.fit_transform(X_train_trf)
X_test_trf = pca.transform(X_test_trf)

# %%
lr = LinearRegression()

lr.fit(X_train_trf,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test_trf)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8164074294266068

# %%
# import plotly.express as px
# 
# y_train_trf = y_train.astype(str)
# fig = px.scatter_3d(df, x=X_train_trf[:, 0], y=X_train_trf[:, 1], z=X_train_trf[:, 2],
#                     color=y_train_trf)
# fig.update_layout(
#     margin=dict(l=20, r=20, t=20, b=20),
#     paper_bgcolor="LightSteelBlue",
# )
# fig.show()
